# %%
import pandas
import os

from collections import defaultdict

# %% [markdown]
# # Isolated Sign Language Recognition

# %%
df = pandas.read_excel('Isolated_Sign_Language_Recognition.xlsx', index_col=0)

# %%
df.head(20)
# Out:
#       Gloss  Split  Video_ID
# 0    feeder  train         1
# 1    feeder  train         2
# 2    feeder  train         3
# 3    feeder    dev         4
# 4    feeder   test         5
# 5     forth  train         6
# 6     forth    dev         7
# 7     forth   test         8
# 8   plaster  train         9
# 9   plaster  train        10
# 10  plaster    dev        11
# 11  plaster   test        12
# 12     soak  train        13
# 13     soak    dev        14
# 14     soak   test        15
# 15  recycle  train        16
# 16  recycle  train        17
# 17  recycle  train        18
# 18  recycle  train        19
# 19  recycle  train        20

# %%
gloss = df.value_counts('Gloss')
gloss.to_dict()
# Out:
# {'sally': 114,
#  'egg': 41,
#  'use': 28,
#  'do': 26,
#  'jay': 20,
#  'tools': 18,
#  'tool': 17,
#  'pattern': 17,
#  'wool': 16,
#  'map': 16,
#  'wood': 15,
#  'ice': 14,
#  'excite': 14,
#  's': 13,
#  'pie': 13,
#  'recycle': 13,
#  'possum': 13,
#  'moon': 13,
#  'min': 12,
#  'curly': 12,
#  'cream': 12,
#  'veg': 11,
#  'glue': 11,
#  'shed': 11,
#  'code': 11,
#  'dr': 11,
#  'dirty': 10,
#  'push': 10,
#  'seed': 10,
#  'goal': 10,
#  'weed': 10,
#  'liquid': 10,
#  'jigsaw': 10,
#  'footprint': 10,
#  'reuse': 10,
#  'reflection': 9,
#  'sumi': 9,
#  'dark': 9,
#  'fresh': 9,
#  'balance': 9,
#  'flour': 9,
#  'third': 9,
#  'compost': 9,
#  'dot': 9,
#  'sandwich': 9,
#  'build': 9,
#  'stir': 9,
#  'craft': 9,
#  'coral': 9,
#  'weave': 9,
#  'awesome': 9,
#  'onion': 9,
#  'oil': 9,
#  'interest': 9,
#  'hurt': 9,
#  'm': 9,
#  'hundred': 9,
#  'underneath': 9,
#  'odd': 9,
#  '5': 8,
#  'left': 8,
#  'shoe': 8,
#  '6': 8,
#  'slow': 8,
#  'spell': 8,
#  'early': 8,
#  'spin': 8,
#  '2': 8,
#  'column': 8,
#  'crater': 8,
#  '12': 8,
#  'muddy': 8,
#  'stack': 8,
#  'container': 8,
#  'pancake': 8,
#  'bad': 8,
#  'if': 8,
#  'bright': 8,
#  'root': 8,
#  'rainbow': 8,
#  'corner': 8,
#  'roof': 8,
#  'rectangle': 8,
#  'rid': 8,
#  'sec': 8,
#  'investigate': 8,
#  'amaze': 8,
#  'bat': 8,
#  'sport': 7,
#  'remind': 7,
#  'front': 7,
#  'group': 7,
#  'spring': 7,
#  'hop': 7,
#  'performance': 7,
#  'rope': 7,
#  'snack': 7,
#  'lucky': 7,
#  'seeds': 7,
#  'pot': 7,
#  'sixty': 7,
#  'cycle': 7,
#  'sad': 7,
#  'deaf': 7,
#  'deliver': 7,
#  'ship': 7,
#  'reflect': 7,
#  'drill': 7,
#  'galley': 7,
#  'mud': 7,
#  'bottle': 7,
#  'tighten': 7,
#  'treasure': 7,
#  'cake': 7,
#  'tail': 7,
#  'to': 7,
#  'chisel': 7,
#  'tomorrow': 7,
#  'climber': 7,
#  'clue': 7,
#  'wave': 7,
#  'assemble': 7,
#  'bottom': 7,
#  'art': 7,
#  'anyone': 7,
#  'arrange': 7,
#  'visitor': 6,
#  'blend': 6,
#  'puzzle': 6,
#  'bush': 6,
#  'freezer': 6,
#  'fine': 6,
#  'better': 6,
#  'high': 6,
#  'sheep': 6,
#  'swing': 6,
#  'doorbell': 6,
#  'finger': 6,
#  'ear': 6,
#  'fork': 6,
#  'easel': 6,
#  'ingredient': 6,
#  'kebab': 6,
#  'brown': 6,
#  'sea': 6,
#  'rung': 6,
#  'faster': 6,
#  'allow': 6,
#  'picnic': 6,
#  'family': 6,
#  'plastic': 6,
#  'scrap': 6,
#  'gravity': 6,
#  'leg': 6,
#  'mind': 6,
#  'shining': 6,
#  'torch': 6,
#  'reason': 6,
#  'solid': 6,
#  'milk': 6,
#  'auslan': 6,
#  'stencil': 6,
#  'cupboard': 6,
#  'steam': 6,
#  'splash': 6,
#  'yummy': 6,
#  'mixed': 6,
#  'stamp': 6,
#  'mixture': 6,
#  'cup': 6,
#  'neat': 6,
#  'clear': 6,
#  'topping': 6,
#  'lever': 6,
#  'healthy': 6,
#  'direction': 6,
#  'gate': 6,
#  'carry': 6,
#  'rake': 6,
#  'windy': 6,
#  'glad': 6,
#  'deep': 6,
#  'lunchtime': 6,
#  'magnifying': 6,
#  'nine': 6,
#  '16': 6,
#  'ramp': 5,
#  'hexagon': 5,
#  'pumpkin': 5,
#  'hide': 5,
#  'attach': 5,
#  'hammer': 5,
#  'queen': 5,
#  'sq': 5,
#  'hr': 5,
#  'parent': 5,
#  '14': 5,
#  'metal': 5,
#  'year': 5,
#  'menu': 5,
#  'mat': 5,
#  'writing': 5,
#  '7': 5,
#  'win': 5,
#  'life': 5,
#  'organize': 5,
#  'pain': 5,
#  'peas': 5,
#  'asleep': 5,
#  'pedal': 5,
#  'peel': 5,
#  'knit': 5,
#  'pen': 5,
#  'recently': 5,
#  'air': 5,
#  'pipe': 5,
#  'plank': 5,
#  'invite': 5,
#  'wanna': 5,
#  'hunt': 5,
#  'pepper': 5,
#  'bear': 5,
#  '11': 5,
#  'drop': 5,
#  'fence': 5,
#  'feeling': 5,
#  'cultivator': 5,
#  'feeder': 5,
#  'farmer': 5,
#  'thinking': 5,
#  'castle': 5,
#  'sway': 5,
#  'boss': 5,
#  'sick': 5,
#  'chat': 5,
#  'bucket': 5,
#  'breeze': 5,
#  'shovel': 5,
#  'school': 5,
#  'scramble': 5,
#  'ruler': 5,
#  'butter': 5,
#  'strip': 5,
#  'tablespoon': 5,
#  'gram': 5,
#  'spot': 5,
#  'b': 5,
#  'baby': 5,
#  'gardening': 5,
#  'comfortable': 5,
#  'full': 5,
#  'eight': 5,
#  'body': 5,
#  'disappear': 5,
#  'tie': 5,
#  'care': 5,
#  'shiny': 5,
#  'coffee': 5,
#  'dog': 5,
#  'oval': 4,
#  'of': 4,
#  'shirt': 4,
#  'nose': 4,
#  'silly': 4,
#  'xray': 4,
#  'shrink': 4,
#  'yard': 4,
#  'swan': 4,
#  'nest': 4,
#  'nervous': 4,
#  'shell': 4,
#  'nap': 4,
#  'mushroom': 4,
#  'smile': 4,
#  'soil': 4,
#  'muffin': 4,
#  'sore': 4,
#  'stuck': 4,
#  'split': 4,
#  'p': 4,
#  'recipe': 4,
#  'weight': 4,
#  'roller': 4,
#  'safely': 4,
#  'ute': 4,
#  'power': 4,
#  'press': 4,
#  'thoughtful': 4,
#  'pull': 4,
#  'rocket': 4,
#  'shelf': 4,
#  'road': 4,
#  'pupa': 4,
#  'repeat': 4,
#  'tonight': 4,
#  'squeeze': 4,
#  'reaction': 4,
#  'wake': 4,
#  'tease': 4,
#  'tape': 4,
#  'savoury': 4,
#  'plaster': 4,
#  'scale': 4,
#  'scarf': 4,
#  'photo': 4,
#  'wavy': 4,
#  'perfectly': 4,
#  'tally': 4,
#  'touch': 4,
#  'shade': 4,
#  'weekend': 4,
#  'swimming': 4,
#  'weigh': 4,
#  'pairs': 4,
#  'pencil': 4,
#  'mess': 4,
#  'costume': 4,
#  'equal': 4,
#  'jar': 4,
#  'join': 4,
#  'artist': 4,
#  'event': 4,
#  'even': 4,
#  'confuse': 4,
#  'arrow': 4,
#  'jacket': 4,
#  'grass': 4,
#  'knot': 4,
#  'arranging': 4,
#  'angle': 4,
#  'electric': 4,
#  'amount': 4,
#  'experiment': 4,
#  'is': 4,
#  'leaky': 4,
#  'bounce': 4,
#  'button': 4,
#  'halve': 4,
#  'chain': 4,
#  'hate': 4,
#  'folding': 4,
#  'helpful': 4,
#  'flip': 4,
#  'famous': 4,
#  'closer': 4,
#  'flap': 4,
#  'hope': 4,
#  'beater': 4,
#  'awake': 4,
#  'favorite': 4,
#  'laugh': 4,
#  'bunch': 4,
#  'dig': 4,
#  'dissolve': 4,
#  '8': 4,
#  'dessert': 4,
#  'mast': 4,
#  'cubbyhouse': 4,
#  'dear': 4,
#  'cute': 4,
#  'across': 4,
#  'lonely': 4,
#  'dish': 4,
#  'lock': 4,
#  'lift': 4,
#  'loop': 4,
#  'adult': 4,
#  'crows': 4,
#  'model': 4,
#  'drip': 4,
#  'cover': 4,
#  'letters': 4,
#  'man': 4,
#  'mistake': 4,
#  'card': 3,
#  'stung': 3,
#  'tag': 3,
#  'suck': 3,
#  'slide': 3,
#  'sultana': 3,
#  'sweet': 3,
#  'snake': 3,
#  'chart': 3,
#  'sunglass': 3,
#  'cog': 3,
#  'cuddle': 3,
#  'curve': 3,
#  'camp': 3,
#  'cultivate': 3,
#  'suspicious': 3,
#  'surprised': 3,
#  'sponge': 3,
#  'stroke': 3,
#  'comb': 3,
#  'cousin': 3,
#  'country': 3,
#  'crash': 3,
#  'sprain': 3,
#  'cough': 3,
#  'sprinkle': 3,
#  'crocodile': 3,
#  'concentrate': 3,
#  'completely': 3,
#  'spanner': 3,
#  'cogs': 3,
#  'steer': 3,
#  'stem': 3,
#  'colored': 3,
#  'collage': 3,
#  'cruel': 3,
#  'spoil': 3,
#  'storyteller': 3,
#  'cucumber': 3,
#  'soak': 3,
#  'mother': 3,
#  'boring': 3,
#  'bubbly': 3,
#  'week': 3,
#  'useful': 3,
#  'valuable': 3,
#  'arm': 3,
#  'antenna': 3,
#  'wall': 3,
#  'warmer': 3,
#  'washing': 3,
#  'wasteful': 3,
#  'wasting': 3,
#  'altogether': 3,
#  'afternoon': 3,
#  'weather': 3,
#  'adventure': 3,
#  'weaving': 3,
#  'action': 3,
#  'tank': 3,
#  'absorb': 3,
#  'wheat': 3,
#  'whistle': 3,
#  'wide': 3,
#  'wilt': 3,
#  'above': 3,
#  '9': 3,
#  '35': 3,
#  'worried': 3,
#  '25': 3,
#  '200': 3,
#  '20': 3,
#  '15': 3,
#  '13': 3,
#  'upstairs': 3,
#  'uniform': 3,
#  'underwater': 3,
#  'underside': 3,
#  'breathe': 3,
#  'brand': 3,
#  'teeth': 3,
#  'ten': 3,
#  'test': 3,
#  'thick': 3,
#  'thicker': 3,
#  'brake': 3,
#  'skin': 3,
#  'throat': 3,
#  'boing': 3,
#  'blunt': 3,
#  'tire': 3,
#  'block': 3,
#  'belong': 3,
#  'begin': 3,
#  'barrow': 3,
#  'bacon': 3,
#  'australia': 3,
#  'track': 3,
#  'tray': 3,
#  'audience': 3,
#  'trigger': 3,
#  'trudge': 3,
#  'trunk': 3,
#  'tv': 3,
#  'twist': 3,
#  'tyre': 3,
#  'umbrella': 3,
#  'skip': 3,
#  'dream': 3,
#  'skim': 3,
#  'pikelets': 3,
#  'koala': 3,
#  'pay': 3,
#  'knowledgeable': 3,
#  'knock': 3,
#  'peeling': 3,
#  'kite': 3,
#  'key': 3,
#  'pendulum': 3,
#  'kettle': 3,
#  'juice': 3,
#  'jug': 3,
#  'pet': 3,
#  'jaw': 3,
#  'pineapple': 3,
#  'lady': 3,
#  'japan': 3,
#  'planet': 3,
#  'jam': 3,
#  'plasticene': 3,
#  'pleasure': 3,
#  'po': 3,
#  'polite': 3,
#  'poor': 3,
#  'improve': 3,
#  'hurry': 3,
#  'powder': 3,
#  'hopscotch': 3,
#  'pretty': 3,
#  'past': 3,
#  'parcel': 3,
#  'proboscis': 3,
#  'oats': 3,
#  'microscope': 3,
#  'meet': 3,
#  'mâché': 3,
#  'measurement': 3,
#  'naughty': 3,
#  'match': 3,
#  'nectar': 3,
#  'marker': 3,
#  'none': 3,
#  'normally': 3,
#  'low': 3,
#  'nowhere': 3,
#  'nut': 3,
#  'obstacle': 3,
#  'pant': 3,
#  'ocean': 3,
#  'office': 3,
#  'organise': 3,
#  'lid': 3,
#  'ourselves': 3,
#  'outdoors': 3,
#  'outline': 3,
#  'letter': 3,
#  'pack': 3,
#  'paddle': 3,
#  'page': 3,
#  'lazy': 3,
#  'pan': 3,
#  'print': 3,
#  'hoist': 3,
#  'skate': 3,
#  'seem': 3,
#  'exhaust': 3,
#  'salt': 3,
#  'exercise': 3,
#  'save': 3,
#  'excursion': 3,
#  'everybody': 3,
#  'scoop': 3,
#  'energetic': 3,
#  'scrape': 3,
#  'screwdriver': 3,
#  'empty': 3,
#  'echidna': 3,
#  'drive': 3,
#  'select': 3,
#  'fact': 3,
#  'shark': 3,
#  'shear': 3,
#  'mouth': 3,
#  'dough': 3,
#  'shine': 3,
#  'disappointed': 3,
#  'digger': 3,
#  'difference': 3,
#  'shoulder': 3,
#  'decide': 3,
#  'damp': 3,
#  'sir': 3,
#  'cushion': 3,
#  'sailboat': 3,
#  'fifth': 3,
#  'herself': 3,
#  'goodbye': 3,
#  'hens': 3,
#  'purple': 3,
#  'hen': 3,
#  'helmet': 3,
#  'race': 3,
#  'heater': 3,
#  'harvest': 3,
#  'reach': 3,
#  'reading': 3,
#  'guest': 3,
#  'groove': 3,
#  'grem': 3,
#  'recognise': 3,
#  'reef': 3,
#  'ruin': 3,
#  'glove': 3,
#  'giant': 3,
#  'frothy': 3,
#  'remove': 3,
#  'forth': 3,
#  'football': 3,
#  'ring': 3,
#  'flatten': 3,
#  'flashing': 3,
#  'fit': 3,
#  'fire': 3,
#  'rotate': 3,
#  'rubbing': 3,
#  'zero': 3}

# %%
potential_words = []
for k,v in gloss.items():
    if v >= 10:
        potential_words.append(k)

potential_words
# Out:
# ['sally',
#  'egg',
#  'use',
#  'do',
#  'jay',
#  'tools',
#  'tool',
#  'pattern',
#  'wool',
#  'map',
#  'wood',
#  'ice',
#  'excite',
#  's',
#  'pie',
#  'recycle',
#  'possum',
#  'moon',
#  'min',
#  'curly',
#  'cream',
#  'veg',
#  'glue',
#  'shed',
#  'code',
#  'dr',
#  'dirty',
#  'push',
#  'seed',
#  'goal',
#  'weed',
#  'liquid',
#  'jigsaw',
#  'footprint',
#  'reuse']

# %%
potential_df = df[df['Gloss'].isin(potential_words)]

# %%
potential_df
# Out:
#         Gloss  Split  Video_ID
# 15    recycle  train        16
# 16    recycle  train        17
# 17    recycle  train        18
# 18    recycle  train        19
# 19    recycle  train        20
# ...       ...    ...       ...
# 2898   possum  train      2899
# 2899   possum  train      2900
# 2900   possum  train      2901
# 2901   possum    dev      2902
# 2902   possum   test      2903
#
# [602 rows x 3 columns]

# %% [markdown]
# # Fingerspelling Detection

# %%
f_df = pandas.read_excel('Fingerspelling_Detection.xlsx', index_col=0)
f_df.head(20)
# Out:
#               Video_Clip_Name  Begin_Frame  End_Frame Finger_Spelling  split
# 0     video_80_130_signer.mp4           56       65.0           E G G  train
# 1    13_11_2022_94_signer.mp4          242      270.0   H A C K E R S  train
# 2      video_47_89_signer.mp4            3       22.0         R O P E  train
# 3      video_81_33_signer.mp4           32       60.0         S H E D    dev
# 4      video_10_78_signer.mp4           29       72.0       T R A C Y  train
# 5      video_86_72_signer.mp4          130      156.0           I C E  train
# 6       video_81_3_signer.mp4           28       56.0       S A L L Y  train
# 7     video_70_190_signer.mp4           65       84.0     W A S H E R  train
# 8   16_10_2022_138_signer.mp4          345      358.0           L A W   test
# 9     13_11_2022_3_signer.mp4          117      133.0           S E S  train
# 10      video_1_57_signer.mp4           17       32.0           C U P  train
# 11    video_65_164_signer.mp4          107      121.0           T I L  train
# 12      video_73_3_signer.mp4           26       53.0       S A L L Y  train
# 13     video_59_53_signer.mp4           74       80.0             S O   test
# 14    video_55_108_signer.mp4           75       95.0             D R  train
# 15     video_42_85_signer.mp4          137      158.0           E G G    dev
# 16   13_11_2022_71_signer.mp4           26       52.0           N S W  train
# 17     video_37_76_signer.mp4           32       50.0           E G G  train
# 18     video_24_13_signer.mp4            3       10.0           U S E   test
# 19    4_12_2022_62_signer.mp4           69       86.0             W D  train

# %%
f_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2004 entries, 0 to 2003
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Video_Clip_Name  2004 non-null   object
#  1   Begin_Frame      2004 non-null   int64
#  2   End_Frame        2003 non-null   float64
#  3   Finger_Spelling  2004 non-null   object
#  4   split            2004 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 93.9+ KB

# %%
f_df[f_df['Video_Clip_Name'] == "4_12_2022_59_signer.mp4"]
# Out:
#               Video_Clip_Name  Begin_Frame  End_Frame Finger_Spelling  split
# 242   4_12_2022_59_signer.mp4          220      233.0         C O A L  train
# 426   4_12_2022_59_signer.mp4           86       96.0             G G  train
# 626   4_12_2022_59_signer.mp4          497      522.0       C O M P O  train
# 1362  4_12_2022_59_signer.mp4          244      251.0             A S  train
# 1534  4_12_2022_59_signer.mp4          439      454.0         C O A L  train
# 1541  4_12_2022_59_signer.mp4          577      586.0             G G  train
# 1601  4_12_2022_59_signer.mp4          272      304.0       C O M P O  train
# 1809  4_12_2022_59_signer.mp4          349      371.0           N S W  train
# 1883  4_12_2022_59_signer.mp4          379      389.0             Q Q   test

# %%
f_df['Video_Clip_Name'].value_counts()
# Out:
# Video_Clip_Name
# 4_12_2022_59_signer.mp4      9
# 13_11_2022_24_signer.mp4     7
# 13_11_2022_68_signer.mp4     6
# 4_12_2022_8_signer.mp4       5
# 13_11_2022_150_signer.mp4    5
#                             ..
# video_59_99_signer.mp4       1
# video_67_101_signer.mp4      1
# video_86_162_signer.mp4      1
# video_55_110_signer.mp4      1
# video_15_60_signer.mp4       1
# Name: count, Length: 1605, dtype: int64

# %%
f_gloss = f_df.value_counts('Finger_Spelling')
f_gloss.to_dict()
# Out:
# {'S A L L Y': 114,
#  'E G G': 43,
#  'U S E': 28,
#  'D O': 27,
#  'G G': 25,
#  'I F': 25,
#  'J A Y': 20,
#  'D R': 19,
#  'N S W': 19,
#  'T O O L S': 18,
#  'P A T T E R N': 17,
#  'T O O L': 17,
#  'R E P': 16,
#  'M A P': 16,
#  'W O O D': 16,
#  'W O O L': 16,
#  'O I L': 15,
#  'M I N': 14,
#  'I C E': 14,
#  'M O O N': 13,
#  'P O S S U M': 13,
#  'P I E': 13,
#  'R E C Y C L E': 13,
#  'S': 13,
#  'C R E A M': 12,
#  'T R U M P': 12,
#  'B I D E N': 11,
#  'C O D E': 11,
#  'S H E D': 11,
#  'T A S': 11,
#  'V E G': 11,
#  'G L U E': 11,
#  'P U S H': 10,
#  'R E U S E': 10,
#  'C U P': 10,
#  'S E E D': 10,
#  'W E E D': 10,
#  'C O A L': 10,
#  'C O R A L': 9,
#  'M E S S I': 9,
#  'F L O U R': 9,
#  'G A S': 9,
#  'N T': 9,
#  'S E C': 9,
#  'S E N A T E': 9,
#  'D E M': 8,
#  'O D D': 8,
#  'C A M P': 8,
#  'P O X': 8,
#  'C O M P O S T': 8,
#  'P A N C A K E': 8,
#  'A B C': 8,
#  'T O': 7,
#  'C L U E': 7,
#  'P O T': 7,
#  'G A L L E Y': 7,
#  'S E E D S': 7,
#  'T R E A S U R E': 7,
#  'V I C': 7,
#  'R O P E': 7,
#  'A R T': 7,
#  'P M': 7,
#  'M U D': 7,
#  'S E S': 6,
#  'A S': 6,
#  'D V': 6,
#  'F I F A': 6,
#  'M I L K': 6,
#  'G R A V I T Y': 6,
#  'S E A': 6,
#  'L A W': 6,
#  'W A': 6,
#  'S T E A M': 6,
#  'S U M I': 6,
#  'B': 5,
#  'S H I N E': 5,
#  'P E A S': 5,
#  'S C H O O L': 5,
#  'H E X A G O N': 5,
#  'I S': 5,
#  'B U T T E R': 5,
#  'N E W S': 5,
#  'M E N U': 5,
#  'P C': 5,
#  'G E O R G I A': 5,
#  'S Q': 5,
#  'T A B L E S P O O N': 5,
#  'C A S T L E': 5,
#  'C R A F T': 5,
#  'H R': 5,
#  'A I R': 5,
#  'F U L L': 5,
#  'N E S T': 4,
#  'D I G': 4,
#  'R O A D': 4,
#  'T V': 4,
#  'C R O W S': 4,
#  'O F': 4,
#  'S O I L': 4,
#  'P U L L': 4,
#  'T A X': 4,
#  'K I N G': 4,
#  'P O W E R': 4,
#  'R E C I P E': 4,
#  'P A I R S': 4,
#  'C H A I N': 4,
#  'Y A R D': 4,
#  'X R A Y': 4,
#  'S T A T E': 4,
#  'A N G L E': 4,
#  'L E T T E R S': 4,
#  'A B C C': 4,
#  'M O D E L': 4,
#  'Q Q': 4,
#  'P L A S T E R': 4,
#  'S A N D B A G S': 4,
#  'M': 4,
#  'R E A C T I O N': 4,
#  'P': 4,
#  'D E A R': 4,
#  'T A L L Y': 4,
#  'E V E N': 4,
#  'C L A Y': 4,
#  'A C C': 4,
#  'F A N S': 4,
#  'S C R A P': 4,
#  'M U F F I N': 4,
#  'S A': 4,
#  'S A V O U R Y': 4,
#  'N E V A D A': 3,
#  'T O N Y   B U R K E': 3,
#  'H W': 3,
#  'M I R I A M   C O R O W A': 3,
#  'S U I C I D E': 3,
#  'E N E R G Y': 3,
#  'T O O': 3,
#  'S I R': 3,
#  'P E T': 3,
#  'S P O N G E': 3,
#  'H E N S': 3,
#  'S K I P': 3,
#  'D R Y': 3,
#  'N D I S': 3,
#  'H A C K E R S': 3,
#  'G R E M': 3,
#  'R E E F': 3,
#  'N E C T A R': 3,
#  'T A N K': 3,
#  'O B S T A C L E': 3,
#  'A C': 3,
#  'C A R D': 3,
#  'L E G': 3,
#  'C O G S': 3,
#  'C O G': 3,
#  'K A M B O S I S': 3,
#  'R Y A N': 3,
#  'P A N': 3,
#  'A S E A N': 3,
#  'L E T T E R': 3,
#  'W H E A T': 3,
#  'U N I O N': 3,
#  'U K': 3,
#  'C O L L A G E': 3,
#  'C A L D': 3,
#  'P O': 3,
#  'K I T E': 3,
#  'C H A R T': 3,
#  'L I D': 3,
#  'P I K E L E T S': 3,
#  'C U C U M B E R': 3,
#  'W D': 3,
#  'R O O T': 3,
#  'O A T S': 3,
#  'I R A N': 3,
#  'L I Q U I D': 3,
#  'R U N': 2,
#  'R A W': 2,
#  'A B C   N E W S': 2,
#  'S A N D': 2,
#  'S P O O N': 2,
#  'G O K A R T': 2,
#  'S P R I N G': 2,
#  'G L A S S': 2,
#  'M A R B L I N G': 2,
#  'R A K E': 2,
#  'G E T': 2,
#  'R A I N S': 2,
#  'R A I N B O W': 2,
#  'S A L T': 2,
#  'A N D': 2,
#  'L I G H T': 2,
#  'B A K E': 2,
#  'H A L F': 2,
#  'G U T T E R': 2,
#  'J O H N S O N': 2,
#  'H U M M U S': 2,
#  'J A M': 2,
#  'F U N': 2,
#  'J A P A N': 2,
#  'S I L H O U E T T E': 2,
#  'M F': 2,
#  'J A R': 2,
#  'M E D I B A N K': 2,
#  'J I G S A W': 2,
#  'S K Y': 2,
#  'H O N E Y C O M B': 2,
#  'R I O T': 2,
#  'J O B': 2,
#  'A L L': 2,
#  'A L V A R E Z': 2,
#  'M A T T   K E A N': 2,
#  'R O C K': 2,
#  'S N A P': 2,
#  'S O': 2,
#  'K E B A B': 2,
#  'H A Y D E N': 2,
#  'K G': 2,
#  'H A N E Y': 2,
#  'M A R K S': 2,
#  'S O M A L I A': 2,
#  'S H E P P A R T O N': 2,
#  'K M': 2,
#  'G W': 2,
#  'F E D   S Q': 2,
#  'S A I L O R': 2,
#  'M I R R O R': 2,
#  'C O T T O N': 2,
#  'C O I L': 2,
#  'V I C N S W': 2,
#  'C O M P O': 2,
#  'A C T': 2,
#  'O L I V E': 2,
#  'P O S S': 2,
#  'C O R T E Z': 2,
#  'C O T T A G E': 2,
#  'U N': 2,
#  'T O N N E': 2,
#  'O D E S A': 2,
#  'U': 2,
#  'C R U T C H E S': 2,
#  'C U P S': 2,
#  'A D A M   L A X A L T': 2,
#  'O': 2,
#  'N Z': 2,
#  'D A T E S': 2,
#  'C O D E S': 2,
#  'O M E L E T T E': 2,
#  'B I L L I E   J E A N': 2,
#  'C L U E S': 2,
#  'P E N D U L U M': 2,
#  'Y E A S T': 2,
#  'B O X': 2,
#  'X I   J I N P I N G': 2,
#  'X': 2,
#  'C A M P A S P E': 2,
#  'P L A N K': 2,
#  'C A R D B O A R D': 2,
#  'C A R D S': 2,
#  'C A T H E R I N E': 2,
#  'C E O': 2,
#  'O V E N': 2,
#  'W E E D S': 2,
#  'C I N N A M O N': 2,
#  'P O C K E T': 2,
#  'W A S H E R': 2,
#  'P O M P O M': 2,
#  'P R E M I E R': 2,
#  'T R I G G E R': 2,
#  'M U S T A R D': 2,
#  'Q F': 2,
#  'M U E S L I': 2,
#  'F F': 2,
#  'A L B A N E S E': 2,
#  'F I L L I N G': 2,
#  'T E A S P O O N': 2,
#  'T': 2,
#  'E N D': 2,
#  'E G G S': 2,
#  'T E N T': 2,
#  'F L O R E N C E': 2,
#  'F': 2,
#  'N E V I L L E': 2,
#  'M O V E M B E R': 2,
#  'F R': 2,
#  'N I': 2,
#  'D O U G H': 2,
#  'M L': 2,
#  'F R E E': 2,
#  'M M': 2,
#  'S W': 2,
#  'M U F F I N S': 2,
#  'D R C': 2,
#  'B A G': 2,
#  'Q A T A R': 1,
#  'P U Z Z L E': 1,
#  'R A D I S H': 1,
#  'R U L E R': 1,
#  'P I N C H': 1,
#  'R A N G E': 1,
#  'P O D': 1,
#  'P O I N T': 1,
#  'A R R O W': 1,
#  'P O L I C E': 1,
#  'P I P E': 1,
#  'P O R N': 1,
#  'P L U M B E R': 1,
#  'Q U A R T E R': 1,
#  'P R I M A R Y': 1,
#  'R O O M': 1,
#  'A P R I L': 1,
#  'P R A K A S H': 1,
#  'R E G A R D S': 1,
#  'A P E C': 1,
#  'P P P': 1,
#  'A Q U A R I U M': 1,
#  'P O T S': 1,
#  'R E P U B L I C': 1,
#  'P R O B O S C I S': 1,
#  'R A F A E L': 1,
#  'R E S T': 1,
#  'A N Z A C': 1,
#  'A P R I C O T S': 1,
#  'R I A': 1,
#  'P R O L A E S E': 1,
#  'R I D E': 1,
#  'A R I M O N A': 1,
#  'R I M E I A': 1,
#  'P R O S T A T E': 1,
#  'P R O T E I N': 1,
#  'R E C T A N G L E': 1,
#  'R O B E R T A   W Y D E R M Y E R': 1,
#  'R E C O R D': 1,
#  'P U L L E Y': 1,
#  'P O R R I D G E': 1,
#  'R E F L E C T': 1,
#  'P U P A': 1,
#  'R O L L E R': 1,
#  'B I R D': 1,
#  'S O A R': 1,
#  'S A M': 1,
#  'U N T I L L': 1,
#  'T U R N I N G': 1,
#  'T U N A': 1,
#  'T U E S': 1,
#  'T T L E M E N T': 1,
#  'T R E A T': 1,
#  'T R A Y': 1,
#  'T R A V I S': 1,
#  'T R A F F I C': 1,
#  'T R A C Y': 1,
#  'T O Y S': 1,
#  'T O W E L': 1,
#  'A L A B A M A': 1,
#  'T O N Y   A B B O T T': 1,
#  'T O M': 1,
#  'T I L': 1,
#  'T I D E S': 1,
#  'T I D E': 1,
#  'T I A N G O N G': 1,
#  'T H I R D S': 1,
#  'T H E': 1,
#  'T E R R O R I S T': 1,
#  'T E R R O R I S M': 1,
#  'T E R M': 1,
#  'T E L E S C O P E': 1,
#  'T E E N': 1,
#  'T E A C H E R': 1,
#  'T E A': 1,
#  'U A W Z': 1,
#  'U P': 1,
#  'S A N D B A G': 1,
#  'A D A M': 1,
#  'Z E R O': 1,
#  'Z': 1,
#  'Y O G H O U R T': 1,
#  'Y D': 1,
#  'W V I': 1,
#  'W R A P': 1,
#  'W O R K S': 1,
#  'W K   V I C': 1,
#  'W I N T E R': 1,
#  'W I L L I A M S': 1,
#  'W I': 1,
#  'W H O L E': 1,
#  'W H O': 1,
#  'W H I P P E D': 1,
#  'W H E E L': 1,
#  'W G': 1,
#  'W E L L': 1,
#  'W E E K': 1,
#  'W A T S O N': 1,
#  'W A S H I N G T O N': 1,
#  'W A S': 1,
#  'W A L N U T': 1,
#  'W A L L A B Y': 1,
#  'W A L K E R': 1,
#  'V P': 1,
#  'V E G G I E': 1,
#  'V A N E': 1,
#  'T A R': 1,
#  'T A P': 1,
#  'T A N A M I': 1,
#  'T A N': 1,
#  'S I M P S O N': 1,
#  'S I D E': 1,
#  'S H R E D D E D': 1,
#  'S H E R E E N   K U M A R': 1,
#  'S H E L L': 1,
#  'A L I C E   S P R I N G S': 1,
#  'S H A R E': 1,
#  'S H A D O W S': 1,
#  'S H A D O W': 1,
#  'S H A D E': 1,
#  'S E X U A L   A S S A U L T': 1,
#  'S E X': 1,
#  'S E O U L': 1,
#  'S E N D I N G': 1,
#  'S E N A T O R': 1,
#  'S E M I F I N A L': 1,
#  'S E K O U': 1,
#  'A L S H A B A A B': 1,
#  'S E C U R I T Y': 1,
#  'S E C O N D': 1,
#  'S C R I B E': 1,
#  'S C R A P S': 1,
#  'S C O R E': 1,
#  'S A Y': 1,
#  'S A T': 1,
#  'S A N D E R S': 1,
#  'S A N D C A S T L E S': 1,
#  'S I Z E': 1,
#  'S L I N K Y': 1,
#  'S M O O T H I E S': 1,
#  'S U M I N A G A S H I': 1,
#  'T A M E': 1,
#  'T A L G E N T Y E R E': 1,
#  'T A I L': 1,
#  'S Y R I A': 1,
#  'S Y M B O L': 1,
#  'S Y': 1,
#  'S W I T C H': 1,
#  'S W A Y': 1,
#  'S W A N': 1,
#  'S U P E R': 1,
#  'S U N F L O W E R': 1,
#  'S U N D I A L': 1,
#  'S U D A N': 1,
#  'S N A C K': 1,
#  'S T O V E': 1,
#  'S T O S U R': 1,
#  'S T O P': 1,
#  'S T A R F I S H': 1,
#  'S T A R': 1,
#  'S T': 1,
#  'S P H E R E': 1,
#  'S P A C E   S T A T I O N': 1,
#  'S O U T H B A N K': 1,
#  'S O O N': 1,
#  'S O L I D': 1,
#  'S O L A R': 1,
#  'P E T R O L E U M': 1,
#  'M O O R O O P N A': 1,
#  'P E N N S Y L V A N I A': 1,
#  'E G': 1,
#  'F D G G': 1,
#  'F A A': 1,
#  'E U R E K A': 1,
#  'E T I W I': 1,
#  'E T H I O P I A': 1,
#  'E S T O N I A': 1,
#  'E S S E N T I A L': 1,
#  'E S P E R A N C E': 1,
#  'E S K': 1,
#  'E R N   K I M B E R L E Y': 1,
#  'E Q': 1,
#  'E N G I N E': 1,
#  'E I V D E S': 1,
#  'B B': 1,
#  'E C O N O M Y': 1,
#  'D I P': 1,
#  'E C H U C A': 1,
#  'E C H U A': 1,
#  'E A S E L': 1,
#  'D U S T': 1,
#  'D U R A L': 1,
#  'D S P': 1,
#  'B B Q': 1,
#  'D O N A L D S O N': 1,
#  'D O M E S T I C   V I O L E N C E': 1,
#  'D O G S': 1,
#  'B B S Y': 1,
#  'D N A': 1,
#  'D M Z': 1,
#  'D L   R O Y A L': 1,
#  'F E R T': 1,
#  'F E T A': 1,
#  'F I N A L': 1,
#  'F L A X': 1,
#  'G R E E T I N G': 1,
#  'G R E A T': 1,
#  'G R A M': 1,
#  'G O U L B U R N': 1,
#  'B A R K L Y': 1,
#  'G I L L A R D': 1,
#  'B A R R E L': 1,
#  'G B S': 1,
#  'G A U G E': 1,
#  'B A R R I E R': 1,
#  'G A L L Y': 1,
#  'F U R': 1,
#  'F U E L': 1,
#  'F R U I T': 1,
#  'F R I E D': 1,
#  'F R E S H': 1,
#  'F R E E R A N G E': 1,
#  'F R A U D': 1,
#  'F O R C E S': 1,
#  'F O R C E': 1,
#  'F O R B E S': 1,
#  'F O R': 1,
#  'F O M E R': 1,
#  'F O L D': 1,
#  'B A S E': 1,
#  'F L O R I S T': 1,
#  'F L O A T': 1,
#  'F L I P': 1,
#  'F L I N D E R S': 1,
#  'D I R T': 1,
#  'D E M O R A T I C': 1,
#  'G U A R D': 1,
#  'C A P S I C U M': 1,
#  'C L A R E': 1,
#  'C I C': 1,
#  'C H I A': 1,
#  'C H A R L T O N': 1,
#  'C H A L K': 1,
#  'C F A': 1,
#  'C E R A M I C': 1,
#  'C E L E R Y': 1,
#  'C C': 1,
#  'C A V A L L O': 1,
#  'C A S A': 1,
#  'C A R T O N': 1,
#  'C A R R O T': 1,
#  'C A R I   L A K E': 1,
#  'C A N C E R': 1,
#  'D E M O C R A T S': 1,
#  'B I N': 1,
#  'C A M I L A': 1,
#  'C A L R C': 1,
#  'C A I R O': 1,
#  'C A C A O': 1,
#  'C A B B A G E': 1,
#  'B U S C H K U E H L': 1,
#  'B R E T T': 1,
#  'B R A N C H': 1,
#  'B O U R K E': 1,
#  'B O O T': 1,
#  'B O N E S': 1,
#  'B O M': 1,
#  'B O L': 1,
#  'C L A R E   O N E I L': 1,
#  'C L A R K': 1,
#  'C L E A N E R': 1,
#  'C L I M A T E': 1,
#  'B E A C H': 1,
#  'D E C A T H L O N': 1,
#  'D A L A S': 1,
#  'D': 1,
#  'C Y C L E': 1,
#  'C Y B E R': 1,
#  'C W': 1,
#  'C U T T I N G': 1,
#  'B E A N': 1,
#  'C R O U T O N S': 1,
#  'C R O S S I N G': 1,
#  'C R I M E A': 1,
#  'C R E S C E N T': 1,
#  'B E D': 1,
#  'C R A T E R S': 1,
#  'C R A C K E R': 1,
#  'C O W': 1,
#  'C O U R S E': 1,
#  'B E E': 1,
#  'C O P': 1,
#  'C O N E S': 1,
#  'B E S T': 1,
#  'C O M M I S S I O N': 1,
#  'C O M A': 1,
#  'C O I N': 1,
#  'B I L L': 1,
#  'C M': 1,
#  'C L O T H': 1,
#  'C L O S E': 1,
#  'G R I N': 1,
#  'H A M I L T O N': 1,
#  'P E A C E F U L': 1,
#  'B A I D O A': 1,
#  'M R   H A S T I N G S': 1,
#  'M P': 1,
#  'M O P': 1,
#  'B O I L E R': 1,
#  'M O O R O O P': 1,
#  'M O A M A': 1,
#  'M I T C H E L L': 1,
#  'M I R I A M': 1,
#  'M I N U T E S': 1,
#  'M I N U T E': 1,
#  'M I N I B U S': 1,
#  'M I N E S': 1,
#  'M I N E': 1,
#  'M I N C E': 1,
#  'M I L L E R': 1,
#  'M A S T': 1,
#  'M I L E S P H': 1,
#  'M I L E': 1,
#  'M I C R O S C O P E': 1,
#  'M E T R E': 1,
#  'M E T   O F F I C E': 1,
#  'M E S H E Z N T': 1,
#  'M E S H': 1,
#  'M E R E D I T H': 1,
#  'M E L T': 1,
#  'M E H': 1,
#  'M E D I A': 1,
#  'M E A Y E S': 1,
#  'M B Y': 1,
#  'M A U N A': 1,
#  'M U R R A Y': 1,
#  'M U R R U M B I D G E E': 1,
#  'N A': 1,
#  'N A I L': 1,
#  'P C F': 1,
#  'P A U L I N E': 1,
#  'P A S T E': 1,
#  'P A R T S': 1,
#  'P A R T': 1,
#  'P A R K O U R': 1,
#  'P A P E R': 1,
#  'P A D D L E': 1,
#  'O V A L': 1,
#  'O U T S T A T I O N': 1,
#  'O R I G A M I': 1,
#  'O R A N G E': 1,
#  'O R': 1,
#  'O P E N': 1,
#  'O L I V E S': 1,
#  'O I L Y': 1,
#  'O C E A N': 1,
#  'N U C L E A R': 1,
#  'N T S': 1,
#  'B A C K': 1,
#  'N S W   R I V E R I N A': 1,
#  'B A C O N': 1,
#  'N O V': 1,
#  'N I N G V': 1,
#  'N I D S': 1,
#  'N E W': 1,
#  'N E E D': 1,
#  'N A S A   H Q': 1,
#  'N A P': 1,
#  'M A S U': 1,
#  'M A R X I S T': 1,
#  'H A T': 1,
#  'H S': 1,
#  'J O H N   H O W A R D': 1,
#  'J I M   C H A L M E R S': 1,
#  'J I M': 1,
#  'B A L L S': 1,
#  'J A W': 1,
#  'J A P A N E S E': 1,
#  'J A C K E T': 1,
#  'I V I E W': 1,
#  'I T O M L J A N O V I C': 1,
#  'I S L A M I S T': 1,
#  'B A R': 1,
#  'I C E B E R G': 1,
#  'B A R B A R A': 1,
#  'H U L L': 1,
#  'H R S': 1,
#  'M A L C O M   T U R N B U L L': 1,
#  'H O W': 1,
#  'H O U R S': 1,
#  'H O T S C O T C H': 1,
#  'H O T': 1,
#  'H O P S C O T C H': 1,
#  'H O O L I N': 1,
#  'H I V E': 1,
#  'H I T T I N G': 1,
#  'H I N H I N B R O O K': 1,
#  'H E R O N': 1,
#  'H E R B S': 1,
#  'H E A T E R': 1,
#  'H E': 1,
#  'H A Y   B R O W N': 1,
#  'J O S H': 1,
#  'J U I C E': 1,
#  'K': 1,
#  'K A N E   M I N I O N': 1,
#  'M A H S A   A M I N I': 1,
#  'M A G N I F Y I N G': 1,
#  'M A C Q U A R I E': 1,
#  'L U K E': 1,
#  'L O G O': 1,
#  'L I T T E R F R E E': 1,
#  'L I T T E R': 1,
#  'L I F E': 1,
#  'L G B T Q': 1,
#  'L E T T U C E': 1,
#  'L E N D   L E A S E': 1,
#  'L E A R N': 1,
#  'L A U N C H': 1,
#  'L A T H E': 1,
#  'L A S S E T E R': 1,
#  'L A S   V E G A S': 1,
#  'L A P S': 1,
#  'L A N O L I N': 1,
#  'L A B O R': 1,
#  'L A B': 1,
#  'K Y V I V': 1,
#  'K T E W R D N': 1,
#  'K O R I R': 1,
#  'K N O T': 1,
#  'K N E A D': 1,
#  'K I L N': 1,
#  'K I L L E R': 1,
#  'K E T T L E': 1,
#  'K A Y A K': 1,
#  'Z O O': 1}

# %%
f_abc = defaultdict(int)

# %%
for word, appear in f_gloss.items():
    chars = word.split(' ')
    # print(chars)
    for c in chars:
        f_abc[c] += appear

f_abc.pop('')
# Out:
# 84

# %%
f_abc = dict(sorted(f_abc.items()))
f_abc
# Out:
# {'A': 868,
#  'B': 150,
#  'C': 416,
#  'D': 313,
#  'E': 955,
#  'F': 141,
#  'G': 320,
#  'H': 162,
#  'I': 457,
#  'J': 45,
#  'K': 105,
#  'L': 676,
#  'M': 328,
#  'N': 433,
#  'O': 669,
#  'P': 330,
#  'Q': 28,
#  'R': 553,
#  'S': 768,
#  'T': 481,
#  'U': 285,
#  'V': 79,
#  'W': 157,
#  'X': 33,
#  'Y': 239,
#  'Z': 16}

# %%
total_samples = 0
for _,v in f_abc.items():
    total_samples += v

print(total_samples)
# Out:
# 9007

# %% [markdown]
# ## Delete videos not used in the DataFrame

# %%
# Directory path
directory_path = '/Users/hanhf/Works/programming/uow-studies/csit998/csit998_ml/data/fingerspelling_detection/raw_data'

# List of files in the DataFrame
files_in_df = set(f_df['Video_Clip_Name'])

# List of files in the directory
files_in_directory = set(os.listdir(directory_path))

# Files to delete (present in the directory but not in the DataFrame)
files_to_delete = files_in_directory - files_in_df

# Delete files
for file_name in files_to_delete:
    file_path = os.path.join(directory_path, file_name)
    if os.path.isfile(file_path):
        os.remove(file_path)
        print(f'Deleted {file_path}')
    else:
        print(f'{file_path} is not a file or does not exist')
