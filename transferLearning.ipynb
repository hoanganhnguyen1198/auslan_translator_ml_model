# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
from pathlib import Path

def imgPaths(filepaths, test_set=False):
    labels = []
    filepaths_str = []  # List to store the string representations of filepaths
    
    for filepath in filepaths:
        # Ensure filepath is a string
        if isinstance(filepath, Path):
            filepath_str = str(filepath)
        elif isinstance(filepath, str):
            filepath_str = filepath
        else:
            raise ValueError("Filepath must be a string or a Path object")

        filepaths_str.append(filepath_str)

        # Use Path methods to handle path separators properly
        path_parts = Path(filepath_str).parts

        if test_set:
            # Handle test set paths
            # Extract the label from the file name or a specific part of the path
            try:
                filename = Path(filepath_str).stem
                label = filename.split('_')[0]  # Assuming labels are prefixed before underscores
            except IndexError:
                label = 'unknown'
        else:
            # Handle training set paths
            try:
                label = path_parts[-2]  # Extract the label (second-to-last segment in the path)
            except IndexError:
                label = 'unknown'

        labels.append(label)
    
    # Create DataFrame
    df = pd.DataFrame({
        'Filepath': filepaths_str,
        'Label': labels
    })

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop=True)
    
    return df

# Create Variables
train_image_dir = Path('data/asl_alphabet/asl_alphabet_train')
train_filepaths = list(train_image_dir.glob(r'**/*.jpg'))

test_image_dir = Path('data/asl_alphabet/asl_alphabet_test')
test_filepaths = list(test_image_dir.glob(r'**/*.jpg'))

# Create DataFrames
train_df = imgPaths(train_filepaths)
test_df = imgPaths(test_filepaths, test_set=True)

# Display DataFrames
print(train_df.head())
print(train_df.shape)
print(test_df.head())
print(test_df.shape)
# Out:
#                                             Filepath  Label
# 0  data/asl_alphabet/asl_alphabet_train/space/spa...  space
# 1    data/asl_alphabet/asl_alphabet_train/N/N197.jpg      N
# 2    data/asl_alphabet/asl_alphabet_train/C/C195.jpg      C
# 3   data/asl_alphabet/asl_alphabet_train/O/O1379.jpg      O
# 4  data/asl_alphabet/asl_alphabet_train/del/del24...    del
# (87000, 2)
#                                          Filepath Label
# 0  data/asl_alphabet/asl_alphabet_test/F_test.jpg     F
# 1  data/asl_alphabet/asl_alphabet_test/J_test.jpg     J
# 2  data/asl_alphabet/asl_alphabet_test/T_test.jpg     T
# 3  data/asl_alphabet/asl_alphabet_test/U_test.jpg     U
# 4  data/asl_alphabet/asl_alphabet_test/C_test.jpg     C
# (29, 2)

# %%
train_df['Label']
# Out:
# 0        space
# 1            N
# 2            C
# 3            O
# 4          del
#          ...
# 86995      del
# 86996        E
# 86997        C
# 86998        M
# 86999        G
# Name: Label, Length: 87000, dtype: object

# %%
train_df['Label'].unique()
# Out:
# array(['space', 'N', 'C', 'O', 'del', 'Z', 'H', 'U', 'X', 'S', 'G', 'L',
#        'E', 'M', 'P', 'J', 'W', 'R', 'Y', 'Q', 'V', 'I', 'B', 'K',
#        'nothing', 'F', 'A', 'T', 'D'], dtype=object)

# %%
import tensorflow as tf

train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2,
    horizontal_flip = True,
    brightness_range=(0.75, 1.3),
    rotation_range=20,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
    validation_split=0.2,
    horizontal_flip = True,
    brightness_range=(0.75, 1.3),
    rotation_range=20,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)

# %%
# reuse all the layers except for the output layer: include_top=False.
pretrainedModel = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg' # reduces each feature map to a single value by averaging,
)

# freeze the reused layers during the first few epochs.
pretrainedModel.trainable = False

# input layer is same.
inputs = pretrainedModel.input

# output layer: add custom layers on top.
x = tf.keras.layers.Dense(128, activation='relu')(pretrainedModel.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(29, activation='softmax')(x)

# create the final model.
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# since the new output layer was initialized randomly it will make large errors (at least during the first few epochs), so
# there will be large error gradients that may wreck the reused weights. To avoid this,
# one approach is to freeze the reused layers during the first few epochs, 
# giving the new layer some time to learn reasonable weights.
# default learning rate (LR) of the Adam optimizer in TensorFlow/Keras is 0.001.
adam = tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
)

# always compile your model after you freeze or unfreeze layers.
model.compile(
    optimizer=adam,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print model summary
model.summary()

# %%
# train the model for a few epochs.
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=2,
    callbacks=[
         tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
         )
     ]
)

# %%
# unfreeze the reused layers.
for layer in model.layers[:-3]:
    layer.trainable = True

# after unfreezing the reused layers, it is usually a good idea to reduce the learning rate.
adam = tf.keras.optimizers.Adam(
    learning_rate=0.00001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam'
)

# compiling the model again.
model.compile(
    optimizer=adam,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# continue training to fine-tune the reused layers.
history = model.fit(
    train_images,
    validation_data=val_images,
    epochs=8,
    callbacks=[
         tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
         )
     ]
)

# %%
model.save('asl_alphabet_classifier.h5')
results = model.evaluate(test_images)
print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))

# DRAW Results
# %matplotlib inline
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# https://www.kaggle.com/code/thesnak/asl-classfier

# %%
import tensorflow as tf
from tensorflow import keras
from keras import saving

# %%
load_model = saving.load_model('asl_alphabet_classifier.keras')
# Out:
# /Users/hanhf/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'Adam', because it has 326 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
load_model.export('models/asl_alphabet_classifier')
# Out:
# INFO:tensorflow:Assets written to: models/asl_alphabet_classifier/assets
# INFO:tensorflow:Assets written to: models/asl_alphabet_classifier/assets
# Saved artifact at 'models/asl_alphabet_classifier'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 29), dtype=tf.float32, name=None)
# Captures:
#   14277577616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277578960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277579344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277578768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277578192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277579920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277581264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277581456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277581072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277580304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277581840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277583184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277583376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277582992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277582224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277583760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277585104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277585296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277584912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277584144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277585680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277587024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277587216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277586832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277586064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277587600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277588944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277589136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277588752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277587984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277589520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277590864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277590672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277590480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14277588368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278590736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278592272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278592464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278592080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278592848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278594384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278593232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278594768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278596112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278596304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278595920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278595152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278596688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278598032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278598224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278597840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278597072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278598608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278600144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278599760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278598992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278600528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278601872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278602064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278601680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278600912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278602448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278603792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278603984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278602832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278605712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278605520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278604752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278605136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279115600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14278591120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279116176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279116560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279121360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279121552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279121168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279123280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279123472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279123088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279122320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279125200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279125392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279127120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279126928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279129232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279128848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279130960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279130768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279493392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279493584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279493968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279495312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279495504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279495120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279494352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279495888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279497232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279497424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279497040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279496272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279497808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279499152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279499344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279498960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279499728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279501072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279501264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279502992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279503184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279502800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279502032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279503568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279504912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279505104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279504720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279503952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279505488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279506832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279507024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279506640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279506256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279934224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279934032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279934992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279935376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279936720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279936912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279936528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279935760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279937296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279938640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279938832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279938448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279939216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279940560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279940368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279939600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279941136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279942480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279942672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279942288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279943056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279944400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279944592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279944208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279943440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279946320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279946512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279948240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279948048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279947280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279950160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279949968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279949776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14279947664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280393168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280394512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280394704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280394320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280393744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280395088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280396432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280396624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280396240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280395472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280397008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280398352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280398544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280398160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280397392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280398928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280400272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280400464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280400080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280399312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280400848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280402192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280402384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280402000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280401232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280402768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280404112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280404304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280403920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280403152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280404688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280406032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280406224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280405840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280405072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280406608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280407952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280408144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280407760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280406992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280407376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280786192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280786000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280393936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280786960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280787344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280788688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280788880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280788496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280787728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280789264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280790800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280789648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280792336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280793104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280793296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   14280793872: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model('models/asl_alphabet_classifier') # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1724153815.578997  300851 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1724153815.579761  300851 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
